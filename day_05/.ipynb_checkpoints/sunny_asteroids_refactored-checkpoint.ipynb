# %%
class IntcodeComputer:
    
    def add(self):
        pos = self.params['pos'] 
        ans = self.params['1'] + self.params['2']
        self.intcode[pos] = ans
        if self.verbose:
            print('\nAdd:', self.params['1'], '+', self.params['2'], '=', ans)
            print('To address:', pos)
            print('Value at', pos, ans)
            
    def mult(self):
        pos = self.params['pos']
        ans = self.params['1'] * self.params['2']
        self.intcode[pos] = ans
        if self.verbose:
            print('\nMult:', self.params['1'], '*', self.params['2'], '=', ans)
            print('To address:', pos)
            print('Value at', pos, ans)
        
    def save(self):        
        pos = self.params['pos']
        if self.verbose:
            print('\nUser Input:')
        if self.interactive:
            user_input = input()
        else:
            user_input = self.inputs[self.inpointer]
            if self.verbose:
                print(self.inputs[self.inpointer])
            self.inpointer += 1
        if self.verbose:
            print('To address:', pos)
        self.intcode[pos] = int(user_input)
        if self.verbose:
            print('Value at', pos, user_input)
        
    def load(self):
        pos = self.params['pos']
        ans = self.intcode[pos]
        self.outputs.append(ans)

    def halt(self):
        print('Intcode Computer Halting')
        print('Last output:', self.outputs[-1])

    def jump_if_true(self):
        pass
    def jump_if_false(self):
        pass
    def less_than(self):
        pass
    def equals(self):
        pass
    
        
    def __init__(self):
        self.inpointer = 0
        self.inputs = []
        self.pointer = 0
        self.intcode = []
        self.opcode = None
        self.params = dict()
        self.modes = dict()
        self.halted = False
        self.outputs = []
        self.verbose = False
        self.interactive = True
        self.operation = {
            '1': self.add,
            '2': self.mult,
            '3': self.save,
            '4': self.load,
            '5': self.jump_if_true,
            '6': self.jump_if_false,
            '7': self.less_than,
            '8': self.equals,
            '99': self.halt
        }
        
    def set_intcode(self, intcode):
        self.intcode = intcode
        
    def set_inputs(self, inputs):
        self.inputs = inputs
        self.interactive = False
    
    def set_verbose(self, verbose):
        self.verbose = verbose
    
    def code_parser(self, bigcode):
        
        #padding extended opcode with extra zeros
        bigcode = str(bigcode)
        bigcode = '0'*(4 - len(bigcode)) + bigcode
        
        if self.verbose:
            print('Padded bigcode:', bigcode)
        
        self.modes.clear()
        self.params.clear()
        self.opcode = int(bigcode[2:])
        self.modes['1'] = int(bigcode[1])
        self.modes['2'] = int(bigcode[0])
    
    def get_params(self):
        
        #add or mult
        if self.opcode in [1,2]:
            for i in [1,2]:
                pos = self.intcode[self.pointer + i]
                print(pos)
                if self.modes[str(i)]:
                    self.params[str(i)] = pos
                else:
                    self.params[str(i)] = self.intcode[pos]
                    
            self.params['pos'] = self.intcode[self.pointer + 3]
            
        #input or output
        elif self.opcode in [3,4]:
            pos = self.intcode[self.pointer + 1]
            self.params['pos'] = pos
            
        #halt
        elif self.opcode in [99]:
            self.halted = True
            
        else:
            print('Bad behavior')
            self.halted = True
    
    def print_state(self):
        for key, value in glados.__dict__.items():
            if str(key) not in ['intcode', 'operation']:
                print(key, value)
                
    def read_step(self):
        self.code_parser(self.intcode[self.pointer])
        self.get_params()
        if self.verbose:
            self.print_state()
        self.operation[str(self.opcode)]()
        if self.verbose:
            print('Jump:', len(self.params) + 1)
            print('\n' + '='*10 + '\n')
        self.pointer += len(self.params) + 1

# %%
input_file = open('input')
intcode = [int(char) for char in input_file.read().split(',')]
input_file.close()

# %%
glados = IntcodeComputer()
glados.set_intcode(intcode)

# %%
while glados.halted == False:
    glados.set_verbose(True)
    glados.read_step()
# Out:
# Padded bigcode: 0003
# inpointer 0
# inputs []
# pointer 0
# opcode 3
# params {'pos': 225}
# modes {'1': 0, '2': 0}
# halted False
# outputs []
# verbose True
# interactive True
#
# User Input:
# 1
# To address: 225
# Value at 225 1
# Jump: 2
#
# ==========
#
# Padded bigcode: 0001
# 225
# 6
# inpointer 0
# inputs []
# pointer 2
# opcode 1
# params {'1': 1, '2': 1100, 'pos': 6}
# modes {'1': 0, '2': 0}
# halted False
# outputs []
# verbose True
# interactive True
#
# Add: 1 + 1100 = 1101
# To address: 6
# Value at 6 1101
# Jump: 4
#
# ==========
#
# Padded bigcode: 1101
# 1
# 238
# inpointer 0
# inputs []
# pointer 6
# opcode 1
# params {'1': 1, '2': 238, 'pos': 225}
# modes {'1': 1, '2': 1}
# halted False
# outputs []
# verbose True
# interactive True
#
# Add: 1 + 238 = 239
# To address: 225
# Value at 225 239
# Jump: 4
#
# ==========
#
# Padded bigcode: 0104
# inpointer 0
# inputs []
# pointer 10
# opcode 4
# params {'pos': 0}
# modes {'1': 1, '2': 0}
# halted False
# outputs []
# verbose True
# interactive True
# Jump: 2
#
# ==========
#
# Padded bigcode: 1101
# 82
# 10
# inpointer 0
# inputs []
# pointer 12
# opcode 1
# params {'1': 82, '2': 10, 'pos': 225}
# modes {'1': 1, '2': 1}
# halted False
# outputs [3]
# verbose True
# interactive True
#
# Add: 82 + 10 = 92
# To address: 225
# Value at 225 92
# Jump: 4
#
# ==========
#
# Padded bigcode: 0101
# 94
# 44
# inpointer 0
# inputs []
# pointer 16
# opcode 1
# params {'1': 94, '2': 71, 'pos': 224}
# modes {'1': 1, '2': 0}
# halted False
# outputs [3]
# verbose True
# interactive True
#
# Add: 94 + 71 = 165
# To address: 224
# Value at 224 165
# Jump: 4
#
# ==========
#
# Padded bigcode: 0101
# -165
# 224
# inpointer 0
# inputs []
# pointer 20
# opcode 1
# params {'1': -165, '2': 165, 'pos': 224}
# modes {'1': 1, '2': 0}
# halted False
# outputs [3]
# verbose True
# interactive True
#
# Add: -165 + 165 = 0
# To address: 224
# Value at 224 0
# Jump: 4
#
# ==========
#
# Padded bigcode: 0004
# inpointer 0
# inputs []
# pointer 24
# opcode 4
# params {'pos': 224}
# modes {'1': 0, '2': 0}
# halted False
# outputs [3]
# verbose True
# interactive True
# Jump: 2
#
# ==========
#
# Padded bigcode: 1002
# 223
# 8
# inpointer 0
# inputs []
# pointer 26
# opcode 2
# params {'1': 0, '2': 8, 'pos': 223}
# modes {'1': 0, '2': 1}
# halted False
# outputs [3, 0]
# verbose True
# interactive True
#
# Mult: 0 * 8 = 0
# To address: 223
# Value at 223 0
# Jump: 4
#
# ==========
#
# Padded bigcode: 0101
# 3
# 224
# inpointer 0
# inputs []
# pointer 30
# opcode 1
# params {'1': 3, '2': 0, 'pos': 224}
# modes {'1': 1, '2': 0}
# halted False
# outputs [3, 0]
# verbose True
# interactive True
#
# Add: 3 + 0 = 3
# To address: 224
# Value at 224 3
# Jump: 4
#
# ==========
#
# Padded bigcode: 0001
# 224
# 223
# inpointer 0
# inputs []
# pointer 34
# opcode 1
# params {'1': 3, '2': 0, 'pos': 223}
# modes {'1': 0, '2': 0}
# halted False
# outputs [3, 0]
# verbose True
# interactive True
#
# Add: 3 + 0 = 3
# To address: 223
# Value at 223 3
# Jump: 4
#
# ==========
#
# Padded bigcode: 1102
# 35
# 77
# inpointer 0
# inputs []
# pointer 38
# opcode 2
# params {'1': 35, '2': 77, 'pos': 225}
# modes {'1': 1, '2': 1}
# halted False
# outputs [3, 0]
# verbose True
# interactive True
#
# Mult: 35 * 77 = 2695
# To address: 225
# Value at 225 2695
# Jump: 4
#
# ==========
#
# Padded bigcode: 1102
# 28
# 71
# inpointer 0
# inputs []
# pointer 42
# opcode 2
# params {'1': 28, '2': 71, 'pos': 225}
# modes {'1': 1, '2': 1}
# halted False
# outputs [3, 0]
# verbose True
# interactive True
#
# Mult: 28 * 71 = 1988
# To address: 225
# Value at 225 1988
# Jump: 4
#
# ==========
#
# Padded bigcode: 1102
# 16
# 36
# inpointer 0
# inputs []
# pointer 46
# opcode 2
# params {'1': 16, '2': 36, 'pos': 225}
# modes {'1': 1, '2': 1}
# halted False
# outputs [3, 0]
# verbose True
# interactive True
#
# Mult: 16 * 36 = 576
# To address: 225
# Value at 225 576
# Jump: 4
#
# ==========
#
# Padded bigcode: 0102
# 51
# 196
# inpointer 0
# inputs []
# pointer 50
# opcode 2
# params {'1': 51, '2': 68, 'pos': 224}
# modes {'1': 1, '2': 0}
# halted False
# outputs [3, 0]
# verbose True
# interactive True
#
# Mult: 51 * 68 = 3468
# To address: 224
# Value at 224 3468
# Jump: 4
#
# ==========
#
# Padded bigcode: 0101
# -3468
# 224
# inpointer 0
# inputs []
# pointer 54
# opcode 1
# params {'1': -3468, '2': 3468, 'pos': 224}
# modes {'1': 1, '2': 0}
# halted False
# outputs [3, 0]
# verbose True
# interactive True
#
# Add: -3468 + 3468 = 0
# To address: 224
# Value at 224 0
# Jump: 4
#
# ==========
#
# Padded bigcode: 0004
# inpointer 0
# inputs []
# pointer 58
# opcode 4
# params {'pos': 224}
# modes {'1': 0, '2': 0}
# halted False
# outputs [3, 0]
# verbose True
# interactive True
# Jump: 2
#
# ==========
#
# Padded bigcode: 0102
# 8
# 223
# inpointer 0
# inputs []
# pointer 60
# opcode 2
# params {'1': 8, '2': 3, 'pos': 223}
# modes {'1': 1, '2': 0}
# halted False
# outputs [3, 0, 0]
# verbose True
# interactive True
#
# Mult: 8 * 3 = 24
# To address: 223
# Value at 223 24
# Jump: 4
#
# ==========
#
# Padded bigcode: 1001
# 224
# 7
# inpointer 0
# inputs []
# pointer 64
# opcode 1
# params {'1': 0, '2': 7, 'pos': 224}
# modes {'1': 0, '2': 1}
# halted False
# outputs [3, 0, 0]
# verbose True
# interactive True
#
# Add: 0 + 7 = 7
# To address: 224
# Value at 224 7
# Jump: 4
#
# ==========
#
# Padded bigcode: 0001
# 223
# 224
# inpointer 0
# inputs []
# pointer 68
# opcode 1
# params {'1': 24, '2': 7, 'pos': 223}
# modes {'1': 0, '2': 0}
# halted False
# outputs [3, 0, 0]
# verbose True
# interactive True
#
# Add: 24 + 7 = 31
# To address: 223
# Value at 223 31
# Jump: 4
#
# ==========
#
# Padded bigcode: 1001
# 48
# 21
# inpointer 0
# inputs []
# pointer 72
# opcode 1
# params {'1': 36, '2': 21, 'pos': 224}
# modes {'1': 0, '2': 1}
# halted False
# outputs [3, 0, 0]
# verbose True
# interactive True
#
# Add: 36 + 21 = 57
# To address: 224
# Value at 224 57
# Jump: 4
#
# ==========
#
# Padded bigcode: 0101
# -57
# 224
# inpointer 0
# inputs []
# pointer 76
# opcode 1
# params {'1': -57, '2': 57, 'pos': 224}
# modes {'1': 1, '2': 0}
# halted False
# outputs [3, 0, 0]
# verbose True
# interactive True
#
# Add: -57 + 57 = 0
# To address: 224
# Value at 224 0
# Jump: 4
#
# ==========
#
# Padded bigcode: 0004
# inpointer 0
# inputs []
# pointer 80
# opcode 4
# params {'pos': 224}
# modes {'1': 0, '2': 0}
# halted False
# outputs [3, 0, 0]
# verbose True
# interactive True
# Jump: 2
#
# ==========
#
# Padded bigcode: 1002
# 223
# 8
# inpointer 0
# inputs []
# pointer 82
# opcode 2
# params {'1': 31, '2': 8, 'pos': 223}
# modes {'1': 0, '2': 1}
# halted False
# outputs [3, 0, 0, 0]
# verbose True
# interactive True
#
# Mult: 31 * 8 = 248
# To address: 223
# Value at 223 248
# Jump: 4
#
# ==========
#
# Padded bigcode: 0101
# 6
# 224
# inpointer 0
# inputs []
# pointer 86
# opcode 1
# params {'1': 6, '2': 0, 'pos': 224}
# modes {'1': 1, '2': 0}
# halted False
# outputs [3, 0, 0, 0]
# verbose True
# interactive True
#
# Add: 6 + 0 = 6
# To address: 224
# Value at 224 6
# Jump: 4
#
# ==========
#
# Padded bigcode: 0001
# 223
# 224
# inpointer 0
# inputs []
# pointer 90
# opcode 1
# params {'1': 248, '2': 6, 'pos': 223}
# modes {'1': 0, '2': 0}
# halted False
# outputs [3, 0, 0, 0]
# verbose True
# interactive True
#
# Add: 248 + 6 = 254
# To address: 223
# Value at 223 254
# Jump: 4
#
# ==========
#
# Padded bigcode: 0002
# 188
# 40
# inpointer 0
# inputs []
# pointer 94
# opcode 2
# params {'1': 70, '2': 77, 'pos': 224}
# modes {'1': 0, '2': 0}
# halted False
# outputs [3, 0, 0, 0]
# verbose True
# interactive True
#
# Mult: 70 * 77 = 5390
# To address: 224
# Value at 224 5390
# Jump: 4
#
# ==========
#
# Padded bigcode: 1001
# 224
# -5390
# inpointer 0
# inputs []
# pointer 98
# opcode 1
# params {'1': 5390, '2': -5390, 'pos': 224}
# modes {'1': 0, '2': 1}
# halted False
# outputs [3, 0, 0, 0]
# verbose True
# interactive True
#
# Add: 5390 + -5390 = 0
# To address: 224
# Value at 224 0
# Jump: 4
#
# ==========
#
# Padded bigcode: 0004
# inpointer 0
# inputs []
# pointer 102
# opcode 4
# params {'pos': 224}
# modes {'1': 0, '2': 0}
# halted False
# outputs [3, 0, 0, 0]
# verbose True
# interactive True
# Jump: 2
#
# ==========
#
# Padded bigcode: 1002
# 223
# 8
# inpointer 0
# inputs []
# pointer 104
# opcode 2
# params {'1': 254, '2': 8, 'pos': 223}
# modes {'1': 0, '2': 1}
# halted False
# outputs [3, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Mult: 254 * 8 = 2032
# To address: 223
# Value at 223 2032
# Jump: 4
#
# ==========
#
# Padded bigcode: 0101
# 2
# 224
# inpointer 0
# inputs []
# pointer 108
# opcode 1
# params {'1': 2, '2': 0, 'pos': 224}
# modes {'1': 1, '2': 0}
# halted False
# outputs [3, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Add: 2 + 0 = 2
# To address: 224
# Value at 224 2
# Jump: 4
#
# ==========
#
# Padded bigcode: 0001
# 224
# 223
# inpointer 0
# inputs []
# pointer 112
# opcode 1
# params {'1': 2, '2': 2032, 'pos': 223}
# modes {'1': 0, '2': 0}
# halted False
# outputs [3, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Add: 2 + 2032 = 2034
# To address: 223
# Value at 223 2034
# Jump: 4
#
# ==========
#
# Padded bigcode: 1101
# 9
# 32
# inpointer 0
# inputs []
# pointer 116
# opcode 1
# params {'1': 9, '2': 32, 'pos': 224}
# modes {'1': 1, '2': 1}
# halted False
# outputs [3, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Add: 9 + 32 = 41
# To address: 224
# Value at 224 41
# Jump: 4
#
# ==========
#
# Padded bigcode: 0101
# -41
# 224
# inpointer 0
# inputs []
# pointer 120
# opcode 1
# params {'1': -41, '2': 41, 'pos': 224}
# modes {'1': 1, '2': 0}
# halted False
# outputs [3, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Add: -41 + 41 = 0
# To address: 224
# Value at 224 0
# Jump: 4
#
# ==========
#
# Padded bigcode: 0004
# inpointer 0
# inputs []
# pointer 124
# opcode 4
# params {'pos': 224}
# modes {'1': 0, '2': 0}
# halted False
# outputs [3, 0, 0, 0, 0]
# verbose True
# interactive True
# Jump: 2
#
# ==========
#
# Padded bigcode: 1002
# 223
# 8
# inpointer 0
# inputs []
# pointer 126
# opcode 2
# params {'1': 2034, '2': 8, 'pos': 223}
# modes {'1': 0, '2': 1}
# halted False
# outputs [3, 0, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Mult: 2034 * 8 = 16272
# To address: 223
# Value at 223 16272
# Jump: 4
#
# ==========
#
# Padded bigcode: 1001
# 224
# 2
# inpointer 0
# inputs []
# pointer 130
# opcode 1
# params {'1': 0, '2': 2, 'pos': 224}
# modes {'1': 0, '2': 1}
# halted False
# outputs [3, 0, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Add: 0 + 2 = 2
# To address: 224
# Value at 224 2
# Jump: 4
#
# ==========
#
# Padded bigcode: 0001
# 223
# 224
# inpointer 0
# inputs []
# pointer 134
# opcode 1
# params {'1': 16272, '2': 2, 'pos': 223}
# modes {'1': 0, '2': 0}
# halted False
# outputs [3, 0, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Add: 16272 + 2 = 16274
# To address: 223
# Value at 223 16274
# Jump: 4
#
# ==========
#
# Padded bigcode: 1102
# 66
# 70
# inpointer 0
# inputs []
# pointer 138
# opcode 2
# params {'1': 66, '2': 70, 'pos': 225}
# modes {'1': 1, '2': 1}
# halted False
# outputs [3, 0, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Mult: 66 * 70 = 4620
# To address: 225
# Value at 225 4620
# Jump: 4
#
# ==========
#
# Padded bigcode: 1002
# 191
# 28
# inpointer 0
# inputs []
# pointer 142
# opcode 2
# params {'1': 31, '2': 28, 'pos': 224}
# modes {'1': 0, '2': 1}
# halted False
# outputs [3, 0, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Mult: 31 * 28 = 868
# To address: 224
# Value at 224 868
# Jump: 4
#
# ==========
#
# Padded bigcode: 0101
# -868
# 224
# inpointer 0
# inputs []
# pointer 146
# opcode 1
# params {'1': -868, '2': 868, 'pos': 224}
# modes {'1': 1, '2': 0}
# halted False
# outputs [3, 0, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Add: -868 + 868 = 0
# To address: 224
# Value at 224 0
# Jump: 4
#
# ==========
#
# Padded bigcode: 0004
# inpointer 0
# inputs []
# pointer 150
# opcode 4
# params {'pos': 224}
# modes {'1': 0, '2': 0}
# halted False
# outputs [3, 0, 0, 0, 0, 0]
# verbose True
# interactive True
# Jump: 2
#
# ==========
#
# Padded bigcode: 0102
# 8
# 223
# inpointer 0
# inputs []
# pointer 152
# opcode 2
# params {'1': 8, '2': 16274, 'pos': 223}
# modes {'1': 1, '2': 0}
# halted False
# outputs [3, 0, 0, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Mult: 8 * 16274 = 130192
# To address: 223
# Value at 223 130192
# Jump: 4
#
# ==========
#
# Padded bigcode: 0101
# 5
# 224
# inpointer 0
# inputs []
# pointer 156
# opcode 1
# params {'1': 5, '2': 0, 'pos': 224}
# modes {'1': 1, '2': 0}
# halted False
# outputs [3, 0, 0, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Add: 5 + 0 = 5
# To address: 224
# Value at 224 5
# Jump: 4
#
# ==========
#
# Padded bigcode: 0001
# 224
# 223
# inpointer 0
# inputs []
# pointer 160
# opcode 1
# params {'1': 5, '2': 130192, 'pos': 223}
# modes {'1': 0, '2': 0}
# halted False
# outputs [3, 0, 0, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Add: 5 + 130192 = 130197
# To address: 223
# Value at 223 130197
# Jump: 4
#
# ==========
#
# Padded bigcode: 0001
# 14
# 140
# inpointer 0
# inputs []
# pointer 164
# opcode 1
# params {'1': 10, '2': 70, 'pos': 224}
# modes {'1': 0, '2': 0}
# halted False
# outputs [3, 0, 0, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Add: 10 + 70 = 80
# To address: 224
# Value at 224 80
# Jump: 4
#
# ==========
#
# Padded bigcode: 0101
# -80
# 224
# inpointer 0
# inputs []
# pointer 168
# opcode 1
# params {'1': -80, '2': 80, 'pos': 224}
# modes {'1': 1, '2': 0}
# halted False
# outputs [3, 0, 0, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Add: -80 + 80 = 0
# To address: 224
# Value at 224 0
# Jump: 4
#
# ==========
#
# Padded bigcode: 0004
# inpointer 0
# inputs []
# pointer 172
# opcode 4
# params {'pos': 224}
# modes {'1': 0, '2': 0}
# halted False
# outputs [3, 0, 0, 0, 0, 0, 0]
# verbose True
# interactive True
# Jump: 2
#
# ==========
#
# Padded bigcode: 1002
# 223
# 8
# inpointer 0
# inputs []
# pointer 174
# opcode 2
# params {'1': 130197, '2': 8, 'pos': 223}
# modes {'1': 0, '2': 1}
# halted False
# outputs [3, 0, 0, 0, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Mult: 130197 * 8 = 1041576
# To address: 223
# Value at 223 1041576
# Jump: 4
#
# ==========
#
# Padded bigcode: 0101
# 2
# 224
# inpointer 0
# inputs []
# pointer 178
# opcode 1
# params {'1': 2, '2': 0, 'pos': 224}
# modes {'1': 1, '2': 0}
# halted False
# outputs [3, 0, 0, 0, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Add: 2 + 0 = 2
# To address: 224
# Value at 224 2
# Jump: 4
#
# ==========
#
# Padded bigcode: 0001
# 224
# 223
# inpointer 0
# inputs []
# pointer 182
# opcode 1
# params {'1': 2, '2': 1041576, 'pos': 223}
# modes {'1': 0, '2': 0}
# halted False
# outputs [3, 0, 0, 0, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Add: 2 + 1041576 = 1041578
# To address: 223
# Value at 223 1041578
# Jump: 4
#
# ==========
#
# Padded bigcode: 1102
# 79
# 70
# inpointer 0
# inputs []
# pointer 186
# opcode 2
# params {'1': 79, '2': 70, 'pos': 225}
# modes {'1': 1, '2': 1}
# halted False
# outputs [3, 0, 0, 0, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Mult: 79 * 70 = 5530
# To address: 225
# Value at 225 5530
# Jump: 4
#
# ==========
#
# Padded bigcode: 1101
# 31
# 65
# inpointer 0
# inputs []
# pointer 190
# opcode 1
# params {'1': 31, '2': 65, 'pos': 225}
# modes {'1': 1, '2': 1}
# halted False
# outputs [3, 0, 0, 0, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Add: 31 + 65 = 96
# To address: 225
# Value at 225 96
# Jump: 4
#
# ==========
#
# Padded bigcode: 1101
# 11
# 68
# inpointer 0
# inputs []
# pointer 194
# opcode 1
# params {'1': 11, '2': 68, 'pos': 225}
# modes {'1': 1, '2': 1}
# halted False
# outputs [3, 0, 0, 0, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Add: 11 + 68 = 79
# To address: 225
# Value at 225 79
# Jump: 4
#
# ==========
#
# Padded bigcode: 1102
# 20
# 32
# inpointer 0
# inputs []
# pointer 198
# opcode 2
# params {'1': 20, '2': 32, 'pos': 224}
# modes {'1': 1, '2': 1}
# halted False
# outputs [3, 0, 0, 0, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Mult: 20 * 32 = 640
# To address: 224
# Value at 224 640
# Jump: 4
#
# ==========
#
# Padded bigcode: 0101
# -640
# 224
# inpointer 0
# inputs []
# pointer 202
# opcode 1
# params {'1': -640, '2': 640, 'pos': 224}
# modes {'1': 1, '2': 0}
# halted False
# outputs [3, 0, 0, 0, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Add: -640 + 640 = 0
# To address: 224
# Value at 224 0
# Jump: 4
#
# ==========
# Padded bigcode: 0004
# inpointer 0
# inputs []
# pointer 206
# opcode 4
# params {'pos': 224}
# modes {'1': 0, '2': 0}
# halted False
# outputs [3, 0, 0, 0, 0, 0, 0, 0]
# verbose True
# interactive True
# Jump: 2
#
# ==========
#
# Padded bigcode: 1002
# 223
# 8
# inpointer 0
# inputs []
# pointer 208
# opcode 2
# params {'1': 1041578, '2': 8, 'pos': 223}
# modes {'1': 0, '2': 1}
# halted False
# outputs [3, 0, 0, 0, 0, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Mult: 1041578 * 8 = 8332624
# To address: 223
# Value at 223 8332624
# Jump: 4
#
# ==========
#
# Padded bigcode: 1001
# 224
# 5
# inpointer 0
# inputs []
# pointer 212
# opcode 1
# params {'1': 0, '2': 5, 'pos': 224}
# modes {'1': 0, '2': 1}
# halted False
# outputs [3, 0, 0, 0, 0, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Add: 0 + 5 = 5
# To address: 224
# Value at 224 5
# Jump: 4
#
# ==========
#
# Padded bigcode: 0001
# 224
# 223
# inpointer 0
# inputs []
# pointer 216
# opcode 1
# params {'1': 5, '2': 8332624, 'pos': 223}
# modes {'1': 0, '2': 0}
# halted False
# outputs [3, 0, 0, 0, 0, 0, 0, 0, 0]
# verbose True
# interactive True
#
# Add: 5 + 8332624 = 8332629
# To address: 223
# Value at 223 8332629
# Jump: 4
#
# ==========
#
# Padded bigcode: 0004
# inpointer 0
# inputs []
# pointer 220
# opcode 4
# params {'pos': 223}
# modes {'1': 0, '2': 0}
# halted False
# outputs [3, 0, 0, 0, 0, 0, 0, 0, 0]
# verbose True
# interactive True
# Jump: 2
#
# ==========
#
# Padded bigcode: 0099
# inpointer 0
# inputs []
# pointer 222
# opcode 99
# params {}
# modes {'1': 0, '2': 0}
# halted True
# outputs [3, 0, 0, 0, 0, 0, 0, 0, 0, 8332629]
# verbose True
# interactive True
# Intcode Computer Halting
# Last output: 8332629
# Jump: 1
#
# ==========
